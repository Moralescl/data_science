# %% [markdown]
# <a href="https://colab.research.google.com/github/Moralescl/data_science/blob/main/ProyectoRobotTrading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Robot Trading

# %% [markdown]
# ##Declación de variables e importar bibliotecas

# %%
global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %% [markdown]
# ##Obteniendo los datos historicos

# %% [markdown]
# Se crea la función importar_base_bitcoin
#
#
# * Se declaran nuevamente las variables gobales
# * Con la biblioteca datatime calculo la fecha de inicio y fin con los formatos %Y-%m-%d
# * Con la biblioteca yfinance se obtienen los datos de BTC-USD con la función download definiendo la fecha de inicio, de fin y el intervalo de tiempo.
# * Se crea un dataframe en pandas con la información

# %%
def importar_base_bitcoin():
  global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
  import yfinance as yf #biblioteca para obtener el precio del bitcoin
  from datetime import datetime, timedelta #bibliotecas para el calculo de dias

  fecha_fin = datetime.today().strftime('%Y-%m-%d')
  fecha_inicio = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
  df_bitcoin =  pd.DataFrame(yf.download('BTC-USD', start=fecha_inicio,end= None, interval='5m')) # se guarda el historico creando un dataframe, cambio la fecha fin a None para que extraiga datos actuales

# %%
importar_base_bitcoin()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ##Obteniendo las tendencias y el precio actual

# %% [markdown]
# Se crea la función extraer_tendencias
# * Se declara de nuevo las variables globales.
# * Con WebScraping accedo a los datos de 'https://coinmarketcap.com/'
# * Busco el valor del precio actual del Bitcoin en Dolares y lo almaceno en precio_actual previamente tratandolo para que sea un float
# * Busco la variación y defino si la tendencia es 'baja' o 'alta',
#
# El valor de variación solo es positivo a pesar de que sea baja.
# Algo particular esque en esta etiqueta div, hay una etiqueta div que contiene información sobre la fecha anterior de la variación.
# En caso de que sea positiva muestra 'icon-Caret-up' y en el caso de que sea negativa 'icon-Caret-down'. Esto define si nuestra tendencia es alta o baja.
#
# ![variación.png](data:image/png;base64,...)

# %%
def extraer_tendencias():
  global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
  from urllib.request import urlopen
  from bs4 import BeautifulSoup

  url = 'https://coinmarketcap.com/'
  response = urlopen(url)
  html = response.read()
  soup = BeautifulSoup(html,'html.parser')
  precio_actual = float(soup.find('div',class_ = 'sc-b3fc6b7-0 dzgUIj').get_text().replace('$','').replace(',',''))
  tendencia = 'baja' if 'down' in soup.find('span',class_ = 'sc-a59753b0-0 ivvJzO').find('span')['class'][0] else 'alta'

# %% [markdown]
# ## Obteniendo la media y limpieza de datos del DF

# %% [markdown]
# Se crea la función limpieza_datos.
# * Declado de nuavo las variables goblales.
# * Creo una copia del df para el tramiendo de datos.
# * Elimino las columnas que tengan el Volumen en 0
# * Calculo los cuartiles q1 y q3
# * Filtro la base para obtener los datos entre los cuartiles 1 y 3
# * Hago el calculo del promedio y lo almaceno en media_bitcoin
#
# No se detectaron valores nulos en el dt.
#
# No se detectaron valores duplicados en el indice.

# %%
df_bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2009 entries, 2024-09-24 00:00:00+00:00 to 2024-10-01 00:05:00+00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2009 non-null   float64
#  1   High       2009 non-null   float64
#  2   Low        2009 non-null   float64
#  3   Close      2009 non-null   float64
#  4   Adj Close  2009 non-null   float64
#  5   Volume     2009 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 109.9 KB

# %%
df_bitcoin.isnull().sum() #Validación de valores nulos. No hay valores nulos.
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_bitcoin.index.duplicated(keep=False).sum() #Validación de duplicidad en el index. No hay duplicidad.
# Out:
# 0

# %%
def limpieza_datos():
  global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
  df_bitcoin_limpio = df_bitcoin
  df_bitcoin_limpio.drop(index=df_bitcoin_limpio.query('Volume==0').index, axis = 0 , inplace=True) #Se elimmina filas con volumen 0
  Q1 = df_bitcoin_limpio['Close'].quantile(0.25)
  Q3 = df_bitcoin_limpio['Close'].quantile(0.75)
  filtro = (df_bitcoin_limpio['Close']>= Q1) & (df_bitcoin_limpio['Close']<= Q3) #filtro los cuartiles 1 y 3 para eliminar los outliers
  media_bitcoin = df_bitcoin_limpio[filtro]['Close'].mean() #obtener el promedio aplicando el filtro

# %% [markdown]
# ##Algoritmo de decisión.

# %% [markdown]
# Se crea la función tomar_decisiones.
# * Se declaran las variables goblales.
# * Defino mi mi vairbales algoritmo_decisión.
#
#
# Si el precio_actual es mayor o igual a la media_bitcoin y además la tendencia es baja se debe guardar 'Vender'
# Si el precio_actual es menor a la media media_bitcoin y además la tendencia es alta se debe guardar 'Comprar'
# Caso contrario se debe guardar 'Esperar'

# %%
def tomar_decisiones():
  global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
  algoritmo_decision = 'Vender'if (precio_actual >= media_bitcoin) & (tendencia == 'baja') \
  else 'Comprar' if (precio_actual < media_bitcoin) & (tendencia == 'alta') \
  else 'Esperar'

# %% [markdown]
# ##Creando la visualización

# %% [markdown]
# Se crea la función visualización:
# * Se crea la columna Promedio con el valor de la media_bitcoin.
# * Con Mathplotlib defino el tamaño del grafico y el titulo
# * Creo la linea de Close
# * Creo la linea de promedio
# * Creo la anotación de la Acción Sugerida
# * Muestro el grafico

# %%
def visualizacion():
  import seaborn as sns
  global df_bitcoin, precio_actual, tendencia, media_bitcoin,  algoritmo_decision
  df_bitcoin['Promedio']= media_bitcoin

  from tempfile import template
  import plotly.express as px
  fig = px.line(df_bitcoin, x=df_bitcoin.index, y = ['Close','Promedio'], title='Robot Trading', hover_data=dict(Open=':,.2f', High =':,.2f', Low=':,.2f', Volume=':,.2f'))

  fig.update_layout(xaxis_title='Fecha',
                    yaxis_title='Precio de Cierre ($)',
                    title={
                    'text': 'Robot Trading',
                    'x': 0.5,               # Centrar el título
                    'xanchor': 'center',
                    'yanchor': 'top'
                    },
                    template='plotly_dark')
  fig.add_annotation(x=df_bitcoin.index[-1], y= df_bitcoin['Close'].iloc[-1], text=f'Recomendación: {algoritmo_decision}', showarrow=True, arrowhead=4)
  fig.show()

# %% [markdown]
# #Automatización

# %% [markdown]
# Para crear la automatización es necesario importar las bibliotecas
# * time, para retrasar el tiempo de ejecución o para defenir con que periodo se debe ejecutar.
# * clear_output de IPython.display para limpiar la pantalla y mostrar el nuevo gráfico de análisis.
#
# Luego se crea un bucle infinito donde se ejecutan las funciones que creamos anteriormente, en cada repetición se limpia la pantalla, se ejecutan las funciones y se espera 5 minutos antes de ejecutarse de nuevo.

# %%
from IPython.display import clear_output
import time
while(True):
  clear_output()
  importar_base_bitcoin()
  extraer_tendencias()
  limpieza_datos()
  tomar_decisiones()
  visualizacion()
  time.sleep(300)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="922a4939-2ef4-4f2d-9ea7-2a6eab902783" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("922a4939-2ef4-4f2d-9ea7-2a6eab902783")) {                    Plotly.newPlot(                        "922a4939-2ef4-4f2d-9ea7-2a6eab902783",                        [{"customdata":[[63134.71875,63229.953125,62867.109375,177149952.0],[63228.55859375,63228.55859375,63008.40625,239081472.0],[62971.48828125,63049.05859375,62971.48828125,119754752.0],[63155.265625,63155.6640625,63109.50390625,27432960.0],[62924.390625,62924.390625,62832.6875,817152.0],[62832.6875,63011.32421875,62832.6875,91475968.0],[62970.78125,62970.78125,62901.53515625,3762176.0],[62825.0234375,62825.0234375,62740.75390625,46510080.0],[62760.32421875,62852.57421875,62760.32421875,47716352.0],[62852.05859375,62895.71484375,62852.05859375,32899072.0],[62927.65234375,62927.65234375,62901.34375,28991488.0],[62903.8046875,62932.27734375,62903.8046875,13682688.0],[63072.33203125,63123.3515625,63072.33203125,102006784.0],[63130.30859375,63131.7734375,63098.9375,27179008.0],[63079.7265625,63079.7265625,63048.86328125,182544384.0],[62991.25,63050.5546875,62991.25,26720256.0],[63059.02734375,63118.78125,63059.02734375,4941824.0],[63333.2421875,63385.421875,63325.49609375,4560896.0],[63329.515625,63329.515625,63289.07421875,2199552.0],[63506.9765625,63524.75,63495.34375,66217984.0],[63559.84765625,63559.84765625,63547.65625,46616576.0],[63648.94921875,63648.94921875,63599.78125,109561856.0],[63631.48828125,63658.82421875,63623.85546875,10942464.0],[63615.0,63615.0,63576.88671875,2551808.0],[63732.19140625,63735.30859375,63717.86328125,35778560.0],[63724.875,63724.875,63711.58203125,3094528.0],[63677.91796875,63797.38671875,63677.91796875,28923904.0],[63752.15234375,63752.15234375,63718.62109375,29931520.0],[63864.84765625,63864.84765625,63807.6953125,26689536.0],[63863.93359375,63914.6328125,63863.93359375,80988160.0],[63900.96875,63900.96875,63867.98046875,9218048.0],[63844.109375,63844.109375,63784.0078125,4763648.0],[63723.45703125,63723.45703125,63687.42578125,72259584.0],[63687.54296875,63687.54296875,63664.73046875,23470080.0],[63664.875,63664.875,63594.3359375,39966720.0],[63598.5703125,63621.36328125,63598.5703125,53569536.0],[63576.32421875,63591.42578125,63518.71484375,16551936.0],[63568.30859375,63583.93359375,63567.703125,13651968.0],[63547.421875,63651.9296875,63547.421875,16171008.0],[63666.5546875,63694.70703125,63660.30859375,23814144.0],[63673.9921875,63673.9921875,63616.8046875,10485760.0],[63608.28515625,63642.78125,63608.28515625,6391808.0],[63670.40234375,63670.40234375,63625.88671875,7641088.0],[63446.6640625,63458.73828125,63413.4921875,9179136.0],[63395.70703125,63403.828125,63395.70703125,6119424.0],[63427.7265625,63485.4765625,63414.54296875,38223872.0],[63477.33203125,63513.47265625,63477.33203125,19972096.0],[63439.58203125,63513.671875,63439.58203125,16867328.0],[63552.98046875,63599.23046875,63552.98046875,17727488.0],[63596.82421875,63596.82421875,63517.82421875,15163392.0],[63527.8984375,63591.375,63527.8984375,9289728.0],[63591.96875,63630.78125,63591.96875,3702784.0],[63599.83203125,63599.83203125,63539.23828125,13389824.0],[63437.2265625,63451.6640625,63426.7421875,25714688.0],[63463.5078125,63534.70703125,63463.5078125,14569472.0],[63476.5234375,63617.46875,63476.5234375,155648.0],[63599.140625,63599.140625,63563.39453125,55570432.0],[63202.47265625,63425.203125,63148.18359375,188110848.0],[63403.34375,63495.69140625,63298.2578125,225310720.0],[63174.4296875,63174.4296875,62891.484375,121251840.0],[62875.31640625,62981.14453125,62875.31640625,190836736.0],[62898.46875,62898.46875,62825.01171875,136962048.0],[62920.890625,63118.28125,62920.890625, ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-93f4b99fdd91> in <cell line: 3>()
#       8   tomar_decisiones()
#       9   visualizacion()
# ---> 10   time.sleep(300)
#
# KeyboardInterrupt:
